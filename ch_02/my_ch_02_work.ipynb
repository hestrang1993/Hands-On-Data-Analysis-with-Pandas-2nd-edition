# %% [markdown]
# # Chapter 02: Working with Pandas ``DataFrame`` Objects
#
# ## Setup
#
# In this section, I will import all of the necessary packages I need.

# %%
# Necessary imports
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating a ``DataFrame`` Object from a CSV File
#
# ### Reading a CSV File
#
# Using ``pd.read_csv()``, I can use pandas to read a CSV file ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Pandas is usually very good at figuring out which options to use based on the input data, so I often won't need to add arguments to the call; however, there are many options available should I need them, some of which include the following:
#
# | Parameter | Purpose |
# | --- | --- |
# | `sep` | Specifies the delimiter |
# | `header` | Row number where the column names are located; the default option has `pandas` infer whether they are present |
# | `names` | List of column names to use as the header |
# | `index_col` | Column to use as the index |
# | `usecols` | Specifies which columns to read in |
# | `dtype` | Specifies data types for the columns |
# | `converters` | Specifies functions for converting data in certain columns |
# | `skiprows` | Rows to skip |
# | `nrows` | Number of rows to read at a time (combine with `skiprows` to read a file bit by bit) |
# | `parse_dates` | Automatically parse columns containing dates into datetime objects |
# | `chunksize` | For reading the file in chunks |
# | `compression` | For reading in compressed files without extracting beforehand |
# | `encoding` | Specifies the file encoding |
#
# Notably, I could pull the data from:
#
# * The csv file stored in the data directory (``data/earthquakes.csv``)
# * The GitHub repository for this book (https://github.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/blob/master/ch_02/data/earthquakes.csv?raw=True)
#
# I will use the pre-downloaded csv file to make this easy on myself.

# %%
csv_file_path = 'data/earthquakes.csv'
"""
str: The path to the earthquake data from September 18, 2018 - October 13, 2018

Obtained from the US Geological Survey (USGS) using the USGS API
"""

df_csv = pd.read_csv(csv_file_path)
"""
pandas.dataframe: The DataFrame we will examine in this notebook.

It will be the test DataFrame used in this notebook.
The DataFrame is built on the CSV file I loaded in before.
"""

df_csv
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# 9328  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.030410   NaN
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.452600   NaN
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018650   NaN
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.016980   NaN
#
#         gap             ids   mag magType  ...  sources     status  \
# 0      85.0    ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1      79.0    ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2      21.0    ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3      39.0    ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4     192.0    ,nc73096941,  2.16      md  ...     ,nc,  automatic
# ...     ...             ...   ...     ...  ...      ...        ...
# 9327  185.0    ,nc73086771,  0.62      md  ...     ,nc,   reviewed
# 9328   50.0    ,ci38063967,  1.00      ml  ...     ,ci,   reviewed
# 9329  276.0  ,pr2018261000,  2.40      md  ...     ,pr,   reviewed
# 9330   61.0    ,ci38063959,  1.10      ml  ...     ,ci,   reviewed
# 9331   39.0    ,ci38063935,  0.66      ml  ...     ,ci,   reviewed
#
#                time                                     title  tsunami  \
# 0     1539475168010             M 1.4 - 9km NE of Aguanga, CA        0
# 1     1539475129610             M 1.3 - 9km NE of Aguanga, CA        0
# 2     1539475062610             M 3.4 - 8km NE of Aguanga, CA        0
# 3     1539474978070             M 0.4 - 9km NE of Aguanga, CA        0
# 4     1539474716050             M 2.2 - 10km NW of Avenal, CA        0
# ...             ...                                       ...      ...
# 9327  1537230228060      M 0.6 - 9km ENE of Mammoth Lakes, CA        0
# 9328  1537230135130               M 1.0 - 3km W of Julian, CA        0
# 9329  1537229908180  M 2.4 - 35km NNE of Hatillo, Puerto Rico        0
# 9330  1537229545350             M 1.1 - 9km NE of Aguanga, CA        0
# 9331  1537228864470             M 0.7 - 9km NE of Aguanga, CA        0
#
#             type                                              types     tz  \
# 0     earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 1     earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 2     earthquake  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0
# 3     earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 4     earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0
# ...          ...                                                ...    ...
# 9327  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 9328  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0
# 9329  earthquake                       ,geoserve,origin,phase-data, -240.0
# 9330  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0
# 9331  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0
#
#             updated                                                url
# 0     1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...
# 1     1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...
# 2     1539536756176  https://earthquake.usgs.gov/earthquakes/eventp...
# 3     1539475196167  https://earthquake.usgs.gov/earthquakes/eventp...
# 4     1539477547926  https://earthquake.usgs.gov/earthquakes/eventp...
# ...             ...                                                ...
# 9327  1537285598315  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328  1537276800970  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329  1537243777410  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330  1537230211640  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331  1537305830770  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [9332 rows x 26 columns]

# %% [markdown]
# ## Inspecting A ``DataFrame`` Object
#
# Now I can check the properties of the ``df_csv`` object. Namely:
#
# ### Whether the ``DataFrame`` Object Is Empty or Not
#
# The ``empty`` property returns a ``False`` value if the ``DataFrame`` object contains data. Otherwise, it returns ``True``.

# %%
# Checks to see if DataFrame object is empty or not
df_csv.empty
# Out:
# False

# %% [markdown]
# ### The Dimensions of the ``DataFrame`` Object
#
# The ``shape`` property returns the number of rows and columnns in the ``DataFrame`` object.

# %%
# Get the shape of the DataFrame object
df_csv.shape
# Out:
# (9332, 26)

# %% [markdown]
# ### The Columns Inside the ``DataFrame`` Object
#
# The ``columns`` property returns the 'key' for all columns in the ``DataFrame`` object.

# %%
df_csv.columns

# Test to see if this returns an iterable item
test = df_csv.columns
for col in test:
    print(col)

# See the original return of df_csv.columns
test
# Out:
# alert
# cdi
# code
# detail
# dmin
# felt
# gap
# ids
# mag
# magType
# mmi
# net
# nst
# place
# rms
# sig
# sources
# status
# time
# title
# tsunami
# type
# types
# tz
# updated
# url
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %% [markdown]
# ### The Head and Tail of the ``DataFrame`` Object
#
# The head of the ``DataFrame`` object can be retrieved by using the ``head()`` method. If no integer argument is passed, then it automatically gets the first 5 rows of data.

# %%
# Get the head of the DataFrame object
df_csv.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 26 columns]

# %% [markdown]
# The tail of the ``DataFrame`` object can be retrieved using the ``tail()`` method (very similar to the ``head()`` method).

# %%
# Get the tail of the DataFrame object
df_csv.tail(2)
# Out:
#      alert  cdi      code                                             detail  \
# 9330   NaN  NaN  38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331   NaN  NaN  38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#          dmin  felt   gap           ids   mag magType  ...  sources    status  \
# 9330  0.01865   NaN  61.0  ,ci38063959,  1.10      ml  ...     ,ci,  reviewed
# 9331  0.01698   NaN  39.0  ,ci38063935,  0.66      ml  ...     ,ci,  reviewed
#
#                time                          title  tsunami        type  \
# 9330  1537229545350  M 1.1 - 9km NE of Aguanga, CA        0  earthquake
# 9331  1537228864470  M 0.7 - 9km NE of Aguanga, CA        0  earthquake
#
#                                                   types     tz        updated  \
# 9330  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537230211640
# 9331  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537305830770
#
#                                                     url
# 9330  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %% [markdown]
# ### The Data Types Within the ``DataFrame`` Object
#
# The ``dtypes`` property returns the type of data within each column of the ``DataFrame`` object.

# %%
# Get the data types in each column of the DataFrame object
df_csv.dtypes
# Out:
# alert       object
# cdi        float64
# code        object
# detail      object
# dmin       float64
# felt       float64
# gap        float64
# ids         object
# mag        float64
# magType     object
# mmi        float64
# net         object
# nst        float64
# place       object
# rms        float64
# sig          int64
# sources     object
# status      object
# time         int64
# title       object
# tsunami      int64
# type        object
# types       object
# tz         float64
# updated      int64
# url         object
# dtype: object

# %% [markdown]
# ### Getting Extra Information and Location of ``null`` Values in the ``DataFrame`` Object
#
# The ``info()`` method returns information about the ``DataFrame`` object. It provides much of the information discussed in the other methods and properties, but also counts the number of ``null`` items in each column of the ``DataFrame`` object. This is a very useful method.

# %%
# Get a lot of information about the DataFrame object
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alert    59 non-null     object
#  1   cdi      329 non-null    float64
#  2   code     9332 non-null   object
#  3   detail   9332 non-null   object
#  4   dmin     6139 non-null   float64
#  5   felt     329 non-null    float64
#  6   gap      6164 non-null   float64
#  7   ids      9332 non-null   object
#  8   mag      9331 non-null   float64
#  9   magType  9331 non-null   object
#  10  mmi      93 non-null     float64
#  11  net      9332 non-null   object
#  12  nst      5364 non-null   float64
#  13  place    9332 non-null   object
#  14  rms      9332 non-null   float64
#  15  sig      9332 non-null   int64
#  16  sources  9332 non-null   object
#  17  status   9332 non-null   object
#  18  time     9332 non-null   int64
#  19  title    9332 non-null   object
#  20  tsunami  9332 non-null   int64
#  21  type     9332 non-null   object
#  22  types    9332 non-null   object
#  23  tz       9331 non-null   float64
#  24  updated  9332 non-null   int64
#  25  url      9332 non-null   object
# dtypes: float64(9), int64(4), object(13)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Describing & Summarizing ``DataFrame`` Objects
#
# The ``describe()`` method will provide a quick summary of all integer and float elements in a ``DataFrame`` object. To be more specific, it provides the following statistics if called without any arguments:
#
# * Count
# * Mean
# * Standard deviation
# * Minimum
# * 25<sup>th</sup> percentile
# * 75<sup>th</sup> percentile
# * Maximum

# %%
# Base describe() method
df_csv.describe()
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 75%      3.300000     0.177250    5.000000   159.000000     1.900000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# min     0.000000     0.000000     0.000000     0.000000  1.537229e+12
# 25%     2.680000     8.000000     0.119675     8.000000  1.537793e+12
# 50%     3.720000    15.000000     0.210000    26.000000  1.538245e+12
# 75%     4.570000    25.000000     0.590000    56.000000  1.538766e+12
# max     9.120000   172.000000     1.910000  2015.000000  1.539475e+12
#
#            tsunami           tz       updated
# count  9332.000000  9331.000000  9.332000e+03
# mean      0.006537  -451.990140  1.538537e+12
# std       0.080589   231.752571  6.564135e+08
# min       0.000000  -720.000000  1.537230e+12
# 25%       0.000000  -540.000000  1.537996e+12
# 50%       0.000000  -480.000000  1.538621e+12
# 75%       0.000000  -480.000000  1.539110e+12
# max       1.000000   720.000000  1.539537e+12

# %% [markdown]
# I can also specify what percentiles I want to use by using the percentile argument (``percentile = [a, b]``), where $0 \leq$ ``a`` $<$ ``b`` $\leq 1$.

# %%
floor = 0.05
"""
float: The lowest percentile to look at
"""
ceiling = 0.95
"""
float: The highest percentile to look at
"""
percentile_range = [floor, ceiling]
"""
list(float, float): The floor and ceiling to use for our example percentile range
"""

# Describe the DataFrame object within a given range
df_csv.describe(percentiles=percentile_range)
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 5%       2.000000     0.005491    1.000000    35.000000    -0.040000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 95%      4.300000     2.678900   40.200000   276.000000     4.400000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# min     0.000000     0.000000     0.000000     0.000000  1.537229e+12
# 5%      0.000000     4.000000     0.030000     0.000000  1.537344e+12
# 50%     3.720000    15.000000     0.210000    26.000000  1.538245e+12
# 95%     6.380000    49.000000     0.960000   298.000000  1.539319e+12
# max     9.120000   172.000000     1.910000  2015.000000  1.539475e+12
#
#            tsunami           tz       updated
# count  9332.000000  9331.000000  9.332000e+03
# mean      0.006537  -451.990140  1.538537e+12
# std       0.080589   231.752571  6.564135e+08
# min       0.000000  -720.000000  1.537230e+12
# 5%        0.000000  -600.000000  1.537387e+12
# 50%       0.000000  -480.000000  1.538621e+12
# 95%       0.000000   -60.000000  1.539400e+12
# max       1.000000   720.000000  1.539537e+12

# %% [markdown]
# The ``include`` argument specifies what data type should be examined.

# %%
data_type = object
"""
object: The data type to test the include argument with
"""
df_csv.describe(include = data_type)
# Out:
#         alert      code                                             detail  \
# count      59      9332                                               9332
# unique      2      9332                                               9332
# top     green  73089491  https://earthquake.usgs.gov/fdsnws/event/1/que...
# freq       58         1                                                  1
#
#                  ids magType   net                   place sources    status  \
# count           9332    9331  9332                    9332    9332      9332
# unique          9332      10    14                    5433      52         2
# top     ,nn00659707,      ml    ak  10km NE of Aguanga, CA    ,ak,  reviewed
# freq               1    6803  3166                     306    2981      7797
#
#                                  title        type  \
# count                             9332        9332
# unique                            7807           5
# top     M 0.4 - 10km NE of Aguanga, CA  earthquake
# freq                                55        9081
#
#                                types  \
# count                           9332
# unique                            42
# top     ,geoserve,origin,phase-data,
# freq                            5301
#
#                                                       url
# count                                                9332
# unique                                               9332
# top     https://earthquake.usgs.gov/earthquakes/eventp...
# freq                                                    1

# %% [markdown]
# Or, if I set ``include = 'all'``, then I'll get a summary of every data type in the ``DataFrame`` object.

# %%
data_type = "all"
"""
str: The data type to test the include argument with
"""
df_csv.describe(include = data_type)
# Out:
#         alert         cdi      code  \
# count      59  329.000000      9332
# unique      2         NaN      9332
# top     green         NaN  73089491
# freq       58         NaN         1
# mean      NaN    2.754711       NaN
# std       NaN    1.010637       NaN
# min       NaN    0.000000       NaN
# 25%       NaN    2.000000       NaN
# 50%       NaN    2.700000       NaN
# 75%       NaN    3.300000       NaN
# max       NaN    8.400000       NaN
#
#                                                    detail         dmin  \
# count                                                9332  6139.000000
# unique                                               9332          NaN
# top     https://earthquake.usgs.gov/fdsnws/event/1/que...          NaN
# freq                                                    1          NaN
# mean                                                  NaN     0.544925
# std                                                   NaN     2.214305
# min                                                   NaN     0.000648
# 25%                                                   NaN     0.020425
# 50%                                                   NaN     0.059050
# 75%                                                   NaN     0.177250
# max                                                   NaN    53.737000
#
#               felt          gap           ids          mag magType  ...  \
# count   329.000000  6164.000000          9332  9331.000000    9331  ...
# unique         NaN          NaN          9332          NaN      10  ...
# top            NaN          NaN  ,nn00659707,          NaN      ml  ...
# freq           NaN          NaN             1          NaN    6803  ...
# mean     12.310030   121.506588           NaN     1.497345     NaN  ...
# std      48.954944    72.962363           NaN     1.203347     NaN  ...
# min       0.000000    12.000000           NaN    -1.260000     NaN  ...
# 25%       1.000000    66.142500           NaN     0.720000     NaN  ...
# 50%       2.000000   105.000000           NaN     1.300000     NaN  ...
# 75%       5.000000   159.000000           NaN     1.900000     NaN  ...
# max     580.000000   355.910000           NaN     7.500000     NaN  ...
#
#         sources    status          time                           title  \
# count      9332      9332  9.332000e+03                            9332
# unique       52         2           NaN                            7807
# top        ,ak,  reviewed           NaN  M 0.4 - 10km NE of Aguanga, CA
# freq       2981      7797           NaN                              55
# mean        NaN       NaN  1.538284e+12                             NaN
# std         NaN       NaN  6.080306e+08                             NaN
# min         NaN       NaN  1.537229e+12                             NaN
# 25%         NaN       NaN  1.537793e+12                             NaN
# 50%         NaN       NaN  1.538245e+12                             NaN
# 75%         NaN       NaN  1.538766e+12                             NaN
# max         NaN       NaN  1.539475e+12                             NaN
#
#             tsunami        type                         types           tz  \
# count   9332.000000        9332                          9332  9331.000000
# unique          NaN           5                            42          NaN
# top             NaN  earthquake  ,geoserve,origin,phase-data,          NaN
# freq            NaN        9081                          5301          NaN
# mean       0.006537         NaN                           NaN  -451.990140
# std        0.080589         NaN                           NaN   231.752571
# min        0.000000         NaN                           NaN  -720.000000
# 25%        0.000000         NaN                           NaN  -540.000000
# 50%        0.000000         NaN                           NaN  -480.000000
# 75%        0.000000         NaN                           NaN  -480.000000
# max        1.000000         NaN                           NaN   720.000000
#
#              updated                                                url
# count   9.332000e+03                                               9332
# unique           NaN                                               9332
# top              NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# freq             NaN                                                  1
# mean    1.538537e+12                                                NaN
# std     6.564135e+08                                                NaN
# min     1.537230e+12                                                NaN
# 25%     1.537996e+12                                                NaN
# 50%     1.538621e+12                                                NaN
# 75%     1.539110e+12                                                NaN
# max     1.539537e+12                                                NaN
#
# [11 rows x 26 columns]

# %% [markdown]
# The ``describe()`` method will even work on columns as well.

# %%
df_csv.felt.describe()
# Out:
# count    329.000000
# mean      12.310030
# std       48.954944
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max      580.000000
# Name: felt, dtype: float64

# %% [markdown]
# There are methods for specific statistics as well. Here is a sampling of them:
#
# | Method | Description | Data types |
# | --- | --- | --- |
# | `count()` | The number of non-null observations | Any |
# | `nunique()` | The number of unique values | Any |
# | `sum()` | The total of the values | Numerical or Boolean |
# | `mean()` | The average of the values | Numerical or Boolean |
# | `median()` | The median of the values | Numerical |
# | `min()` | The minimum of the values | Numerical |
# | `idxmin()` | The index where the minimum values occurs | Numerical |
# | `max()` | The maximum of the values | Numerical |
# | `idxmax()` | The index where the maximum value occurs | Numerical |
# | `abs()` | The absolute values of the data | Numerical |
# | `std()` | The standard deviation | Numerical |
# | `var()` | The variance |  Numerical |
# | `cov()` | The covariance between two `Series`, or a covariance matrix for all column combinations in a `DataFrame` | Numerical |
# | `corr()` | The correlation between two `Series`, or a correlation matrix for all column combinations in a `DataFrame` | Numerical |
# | `quantile()` | Calculates a specific quantile | Numerical |
# | `cumsum()` | The cumulative sum | Numerical or Boolean |
# | `cummin()` | The cumulative minimum | Numerical |
# | `cummax()` | The cumulative maximum | Numerical |
#
# Note that `Index` objects also have several methods to help describe and summarize our data:
#
# | Method | Description |
# | --- | --- |
# | `argmax()`/`argmin()` | Find the location of the maximum/minimum value in the index |
# | `equals()` | Compare the index to another `Index` object for equality |
# | `isin()` | Check if the index values are in a list of values and return an array of Booleans |
# | `max()`/`min()` | Find the maximum/minimum value in the index |
# | `nunique()` | Get the number of unique values in the index |
# | `to_series()` | Create a `Series` object from the index |
# | `unique()` | Find the unique values of the index |
# | `value_counts()`| Create a frequency table for the unique values in the index |

# %% [markdown]
# ## Subsetting Data in a ``DataFrame`` Object
#
# ### Selecting Columns from the ``DataFrame`` Object Using Attributes
#
# I can use attribute notation to get all the elements in a specific column.

# %%
# Retrieve a column using attributes
df_csv.time
# Out:
# 0       1539475168010
# 1       1539475129610
# 2       1539475062610
# 3       1539474978070
# 4       1539474716050
#             ...
# 9327    1537230228060
# 9328    1537230135130
# 9329    1537229908180
# 9330    1537229545350
# 9331    1537228864470
# Name: time, Length: 9332, dtype: int64

# %% [markdown]
# ### Selecting Columns from the ``DataFrame`` Object Using Dictionary Syntax
#
# I can also use dictionary syntax to grab all the information I can from a specific column in a ``DataFrame`` object.

# %%
# Retrieve a column using dictionaries
first_column_to_get = 'time'
"""
str: A unique column header from my DataFrame instance.

Used to test getting one or more columns from a pandas DataFrame.
"""
df_csv[first_column_to_get]
# Out:
# 0       1539475168010
# 1       1539475129610
# 2       1539475062610
# 3       1539474978070
# 4       1539474716050
#             ...
# 9327    1537230228060
# 9328    1537230135130
# 9329    1537229908180
# 9330    1537229545350
# 9331    1537228864470
# Name: time, Length: 9332, dtype: int64

# %% [markdown]
# In fact, I can use dictionary syntax to get more than one column at a time.

# %%
# Retrieving more than one column using dictionaries
second_column_to_get = 'title'
"""
str: A unique column header from my DataFrame instance.

Used to test getting one or more columns from a pandas DataFrame.
"""
columns_dictionary = [first_column_to_get, second_column_to_get]
"""
list(str, str): A dictionary containing two or more column headings from my DataFrame instance.
"""
df_csv[columns_dictionary]
# Out:
#                time                                     title
# 0     1539475168010             M 1.4 - 9km NE of Aguanga, CA
# 1     1539475129610             M 1.3 - 9km NE of Aguanga, CA
# 2     1539475062610             M 3.4 - 8km NE of Aguanga, CA
# 3     1539474978070             M 0.4 - 9km NE of Aguanga, CA
# 4     1539474716050             M 2.2 - 10km NW of Avenal, CA
# ...             ...                                       ...
# 9327  1537230228060      M 0.6 - 9km ENE of Mammoth Lakes, CA
# 9328  1537230135130               M 1.0 - 3km W of Julian, CA
# 9329  1537229908180  M 2.4 - 35km NNE of Hatillo, Puerto Rico
# 9330  1537229545350             M 1.1 - 9km NE of Aguanga, CA
# 9331  1537228864470             M 0.7 - 9km NE of Aguanga, CA
#
# [9332 rows x 2 columns]

# %% [markdown]
# Using ``dict`` to get columns can be even more powerful if I combine it with list comprehensions and string operations.

# %%
# Create a new columns dictionary using list comprehension and string operations
columns_dictionary = columns_dictionary + [column for column in df_csv.columns if column.startswith('mag')]
columns_dictionary
# Out:
# ['time', 'title', 'mag', 'magType']

# %%
df_csv[columns_dictionary]
# Out:
#                time                                     title   mag magType
# 0     1539475168010             M 1.4 - 9km NE of Aguanga, CA  1.35      ml
# 1     1539475129610             M 1.3 - 9km NE of Aguanga, CA  1.29      ml
# 2     1539475062610             M 3.4 - 8km NE of Aguanga, CA  3.42      ml
# 3     1539474978070             M 0.4 - 9km NE of Aguanga, CA  0.44      ml
# 4     1539474716050             M 2.2 - 10km NW of Avenal, CA  2.16      md
# ...             ...                                       ...   ...     ...
# 9327  1537230228060      M 0.6 - 9km ENE of Mammoth Lakes, CA  0.62      md
# 9328  1537230135130               M 1.0 - 3km W of Julian, CA  1.00      ml
# 9329  1537229908180  M 2.4 - 35km NNE of Hatillo, Puerto Rico  2.40      md
# 9330  1537229545350             M 1.1 - 9km NE of Aguanga, CA  1.10      ml
# 9331  1537228864470             M 0.7 - 9km NE of Aguanga, CA  0.66      ml
#
# [9332 rows x 4 columns]

# %% [markdown]
# ### Slicing ``DataFrame`` Objects
#
# I can index my ``DataFrame`` instance like so:
#
# ```python
# DataFrame[row_start:row_stop]
# ```
#
# Be aware the ``row_start`` argument will be *inclusive* whereas the ``row_stop`` argument will be **exclusive**.

# %%
row_start = 101
"""
int: The row to start the slice at.

This is an inclusive value.
"""
row_stop = 104
"""
int: The row I need to stop.

This is an exclusive value.
"""
df_csv[row_start: row_stop]
# Out:
#     alert  cdi      code                                             detail  \
# 101   NaN  NaN  73096756  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 102   NaN  NaN  37388730  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 103   NaN  NaN  37388722  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...  sources  \
# 101  0.01355   NaN  185.0  ,nc73096756,  0.59      md  ...     ,nc,
# 102  0.02987   NaN   39.0  ,ci37388730,  1.33      ml  ...     ,ci,
# 103  0.03667   NaN  183.0  ,ci37388722,  0.03      ml  ...     ,ci,
#
#         status           time                                 title  tsunami  \
# 101  automatic  1539435391320  M 0.6 - 8km ESE of Mammoth Lakes, CA        0
# 102  automatic  1539435293090        M 1.3 - 8km ENE of Aguanga, CA        0
# 103  automatic  1539434854250           M 0.0 - 5km WSW of Anza, CA        0
#
#            type                                              types     tz  \
# 101  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0
# 102  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0
# 103  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
#
#            updated                                                url
# 101  1539439802162  https://earthquake.usgs.gov/earthquakes/eventp...
# 102  1539435940470  https://earthquake.usgs.gov/earthquakes/eventp...
# 103  1539435060684  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [3 rows x 26 columns]

# %% [markdown]
# I can chain a column slice and a row slice together to get select data from my ``DataFrame`` object.

# %%
df_csv[columns_dictionary][row_start: row_stop]
# Out:
#               time                                 title   mag magType
# 101  1539435391320  M 0.6 - 8km ESE of Mammoth Lakes, CA  0.59      md
# 102  1539435293090        M 1.3 - 8km ENE of Aguanga, CA  1.33      ml
# 103  1539434854250           M 0.0 - 5km WSW of Anza, CA  0.03      ml

# %% [markdown]
# ### Indexing a ``DataFrame`` Object
#
# #### Indexing a ``DataFrame`` Object Using the ``loc`` Attribute
#
# I can use the ``loc`` attribute to pull out specific ranges of my ``DataFrame``. All I need to do is set up code like this:
#
# ```python
# DataFrame.loc[row_indexer, column_indexer]
# ```
# Note that the ``row_indexer`` must be an ``int:int`` argument and the ``column_indexer`` must be a ``str`` or ``[str,str,...]`` argument. Also, ``loc`` is *inclusive* with its ``row_indexer``.
#
# <div class='alert alert-info' role='alert'>
#     By using a <code>:</code> for the <code>row_indexer</code>, I can retrieve all of the elements from a given column/columns.
# </div>

# %%
# Indexing with loc
df_csv.loc[row_start:row_stop, columns_dictionary]
# Out:
#               time                                 title   mag magType
# 101  1539435391320  M 0.6 - 8km ESE of Mammoth Lakes, CA  0.59      md
# 102  1539435293090        M 1.3 - 8km ENE of Aguanga, CA  1.33      ml
# 103  1539434854250           M 0.0 - 5km WSW of Anza, CA  0.03      ml
# 104  1539434531500  M 1.6 - 10km S of Progreso, B.C., MX  1.64      ml

# %% [markdown]
# #### Indexing a ``DataFrame`` Object Using the ``iloc`` Attribute
#
# I can use the ``iloc`` attribute to pull out specific ranges of my ``DataFrame`` in a very similar fashion to the ``loc``. The differences are that both the ``row_indexer`` and ``column_indexer`` must be ``int`` arguments, and the ``row_indexer`` is **exclusive**.

# %%
# Indexing with iloc
first_column_to_get_index = 18
second_column_to_get_index = 19
columns_to_get_indices = [first_column_to_get_index, second_column_to_get_index]
df_csv.iloc[row_start: row_stop + 1, columns_to_get_indices]
# Out:
#               time                                 title
# 101  1539435391320  M 0.6 - 8km ESE of Mammoth Lakes, CA
# 102  1539435293090        M 1.3 - 8km ENE of Aguanga, CA
# 103  1539434854250           M 0.0 - 5km WSW of Anza, CA
# 104  1539434531500  M 1.6 - 10km S of Progreso, B.C., MX

# %% [markdown]
# ### Looking Up Scalar Values in a ``DataFrame`` Object
#
# #### Looking Up Scalar Values in a ``DataFrame`` Object Using ``at``
#
# By using ``at``, I can get the element at a specific row and column.

# %%
# Scalars with at
test_row = 10
"""
int: A random row to test at and iat with.
"""
test_column_title = 'mag'
"""
str: A random column heading to test at with.
"""
df_csv.at[test_row, test_column_title]
# Out:
# 0.5

# %% [markdown]
# #### Looking Up Scalar Values in a ``DataFrame`` Object Using ``iat``
#
# ``iat`` is very similar to ``at``, except that the column argument is an ``int`` index, not a string.

# %%
# Scalars with iat
test_column_index = 8
"""
int: A random column index to test iat with.
"""
df_csv.iat[test_row, test_column_index]
# Out:
# 0.5

# %% [markdown]
# ### Filtering a ``DataFrame`` Object
#
# #### Using Boolean Masks to Filter a ``DataFrame`` Object
#
# A **Boolean mask** filters elements based upon a specific argument and returns values that meet that argument.

# %%
# Boolean mask on a column
bool_mag_value = 7.0
"""
float: The magnitude of the earthquake I want to filter for.
"""
df_csv.mag > bool_mag_value
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9327    False
# 9328    False
# 9329    False
# 9330    False
# 9331    False
# Name: mag, Length: 9332, dtype: bool

# %% [markdown]
# By placing a Boolean mask within bracket, I can return a selection from the ``DataFrame`` instance of all rows that meet that criteria.

# %%
# Boolean mask on a selection
df_csv[df_csv.mag >= bool_mag_value]
# Out:
#       alert  cdi      code                                             detail  \
# 837   green  4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5263    red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap                                 ids  mag magType  ...  \
# 837   1.763   3.0  14.0  ,us1000haa3,pt18283003,at00pgehsk,  7.0     mww  ...
# 5263  1.589  18.0  27.0             ,us1000h3p4,us1000h4p4,  7.5     mww  ...
#
#          sources    status           time  \
# 837   ,us,pt,at,  reviewed  1539204500290
# 5263     ,us,us,  reviewed  1538128963480
#
#                                            title  tsunami        type  \
# 837   M 7.0 - 117km E of Kimbe, Papua New Guinea        1  earthquake
# 5263           M 7.5 - 78km N of Palu, Indonesia        1  earthquake
#
#                                                   types     tz        updated  \
# 837   ,dyfi,finite-fault,general-text,geoserve,groun...  600.0  1539378744253
# 5263  ,dyfi,finite-fault,general-text,geoserve,groun...  480.0  1539123134531
#
#                                                     url
# 837   https://earthquake.usgs.gov/earthquakes/eventp...
# 5263  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %% [markdown]
# Boolean masks also work with ``loc`` indices.

# %%
# Boolean mask + loc
df_csv.loc[
    df_csv.mag >= bool_mag_value,
    columns_dictionary
]
# Out:
#                time                                       title  mag magType
# 837   1539204500290  M 7.0 - 117km E of Kimbe, Papua New Guinea  7.0     mww
# 5263  1538128963480           M 7.5 - 78km N of Palu, Indonesia  7.5     mww

# %% [markdown]
# Using the Boolean operators ``&`` (AND) and ``|`` (OR) around two or more Boolean masks surrounded by parentheses will allow me to filter through ``DataFrame`` objects using more than one criteria.

# %%
bool_alert_value = 'red'
"""
str: The boolean value for the alert I want to filter for.

This argument can either be ``red`` or ``green``.
"""
## Using & with Boolean masks.
df_csv.loc[
    (df_csv.tsunami >= 1) & (df_csv.alert == bool_alert_value),
    columns_dictionary
]
# Out:
#                time                              title  mag magType
# 5263  1538128963480  M 7.5 - 78km N of Palu, Indonesia  7.5     mww

# %%
## Using | with Boolean masks.
df_csv.loc[
    (df_csv.tsunami >= 1) | (df_csv.alert == bool_alert_value),
    columns_dictionary
]
# Out:
#                time                                              title  mag  \
# 36    1539459504090  M 5.0 - 165km NNW of Flying Fish Cove, Christm...  5.0
# 118   1539429023560            M 6.7 - 262km NW of Ozernovskiy, Russia  6.7
# 501   1539312723620        M 5.6 - 128km SE of Kimbe, Papua New Guinea  5.6
# 799   1539213362130         M 6.5 - 148km S of Severo-Kuril'sk, Russia  6.5
# 816   1539208835130        M 6.2 - 94km SW of Kokopo, Papua New Guinea  6.2
# ...             ...                                                ...  ...
# 8561  1537427126700         M 5.4 - 228km S of Taron, Papua New Guinea  5.4
# 8624  1537411002190       M 5.1 - 278km SE of Pondaguitan, Philippines  5.1
# 9133  1537274456960               M 5.1 - 64km SSW of Kaktovik, Alaska  5.1
# 9175  1537262729590                M 5.2 - 126km N of Dili, East Timor  5.2
# 9304  1537236235470   M 5.1 - 34km NW of Finschhafen, Papua New Guinea  5.1
#
#      magType
# 36       mww
# 118      mww
# 501      mww
# 799      mww
# 816      mww
# ...      ...
# 8561      mb
# 8624      mb
# 9133      ml
# 9175      mb
# 9304      mb
#
# [61 rows x 4 columns]

# %% [markdown]
# #### Using the ``notnull()`` Method to Filter a ``DataFrame`` Object
#
# To get not-null elements from a column in a ``DataFrame`` instance, I can use the ``notnull()`` method to return.

# %%
location_to_check = 'Alaska'
"""
str: A location I want to see whether they've had earthquakes or not.
"""
# Filtering for all earthquakes occurring in Alaska.
# Use the notnull() method to return instances of earthquakes that triggered alerts.
columns_dictionary = [
    'alert',
    'mag',
    'magType',
    'title',
    'tsunami',
    'type'
]
df_csv.loc[(df_csv.place.str.contains(location_to_check)) & (df_csv.alert.notnull()), columns_dictionary]
# Out:
#       alert  mag magType                                        title  \
# 1015  green  5.0      ml     M 5.0 - 61km SSW of Chignik Lake, Alaska
# 1273  green  4.0      ml          M 4.0 - 71km SW of Kaktovik, Alaska
# 1795  green  4.0      ml           M 4.0 - 60km WNW of Valdez, Alaska
# 2752  green  4.0      ml         M 4.0 - 67km SSW of Kaktovik, Alaska
# 3260  green  3.9      ml       M 3.9 - 44km N of North Nenana, Alaska
# 4101  green  4.2      ml  M 4.2 - 131km NNW of Arctic Village, Alaska
# 6897  green  3.8      ml         M 3.8 - 80km SSW of Kaktovik, Alaska
# 8524  green  3.8      ml         M 3.8 - 69km SSW of Kaktovik, Alaska
# 9133  green  5.1      ml         M 5.1 - 64km SSW of Kaktovik, Alaska
#
#       tsunami        type
# 1015        1  earthquake
# 1273        1  earthquake
# 1795        1  earthquake
# 2752        1  earthquake
# 3260        0  earthquake
# 4101        0  earthquake
# 6897        0  earthquake
# 8524        0  earthquake
# 9133        1  earthquake

# %% [markdown]
# #### Using Regular Expressions to Filter a ``DataFrame`` Object
#
# I can even use regular expressions to filter a ``DataFrame`` instance.

# %%
mag_filter = 3.8
"""
float: The magnitude to use for this filter test.
"""
df_csv.loc[(df_csv.place.str.contains(r'CA|California$')) & (df_csv.mag > mag_filter), columns_dictionary]
# Out:
#       alert   mag magType                              title  tsunami  \
# 1465  green  3.83      mw  M 3.8 - 109km WNW of Trinidad, CA        0
# 2414  green  3.83      mw   M 3.8 - 5km SW of Tres Pinos, CA        1
#
#             type
# 1465  earthquake
# 2414  earthquake

# %% [markdown]
# #### Using the ``between()`` Method to Filter a ``DataFrame`` Object
#
# I can also use the ``between(a, b)`` to filter all ``int`` or ``float`` values ``a`` $ \leq x \leq $ ``b``.

# %%
min_mag = 6.5
"""
float: The minimum magnitude to include in the filter.
"""
max_mag = 7.5
"""
float: The maximum magnitude to include in the filter.
"""
df_csv.loc[df_csv.mag.between(min_mag, max_mag), columns_dictionary]
# Out:
#       alert  mag magType                                       title  tsunami  \
# 118   green  6.7     mww     M 6.7 - 262km NW of Ozernovskiy, Russia        1
# 799   green  6.5     mww  M 6.5 - 148km S of Severo-Kuril'sk, Russia        1
# 837   green  7.0     mww  M 7.0 - 117km E of Kimbe, Papua New Guinea        1
# 4363  green  6.7     mww      M 6.7 - 263km NNE of Ndoi Island, Fiji        1
# 5263    red  7.5     mww           M 7.5 - 78km N of Palu, Indonesia        1
#
#             type
# 118   earthquake
# 799   earthquake
# 837   earthquake
# 4363  earthquake
# 5263  earthquake

# %% [markdown]
# #### Using the ``isin()`` Method to Filter a ``DataFrame`` Object
#
# I can use the ``isin()`` method to check for membership in a ``DataFrame`` instance.

# %%
isin_dict = ['mw', 'mwb']
"""
list(str, str): The items to use as a filter for a column.

I'll use this dictionary to return rows with either a `mw` element or a `mwb` element in the `magType` column.
"""
df_csv.loc[df_csv.magType.isin(isin_dict), columns_dictionary]
# Out:
#       alert   mag magType                                   title  tsunami  \
# 995     NaN  3.35      mw             M 3.4 - 9km WNW of Cobb, CA        0
# 1465  green  3.83      mw       M 3.8 - 109km WNW of Trinidad, CA        0
# 2414  green  3.83      mw        M 3.8 - 5km SW of Tres Pinos, CA        1
# 4988  green  4.41      mw       M 4.4 - 1km SE of Delta, B.C., MX        1
# 6307  green  5.80     mwb  M 5.8 - 297km NNE of Ndoi Island, Fiji        0
# 8257  green  5.70     mwb      M 5.7 - 175km SSE of Lambasa, Fiji        0
#
#             type
# 995   earthquake
# 1465  earthquake
# 2414  earthquake
# 4988  earthquake
# 6307  earthquake
# 8257  earthquake

# %% [markdown]
# #### Using the ``idxmin()`` and ``idxmax()`` Methods to Filter a ``DataFrame`` Object
#
# The ``idxmin()`` and ``idxmax()`` can be used to return the minimum and maximum value from a column in a ``DataFrame`` instance.

# %%
mag_min_max_dict = [df_csv.mag.idxmin(), df_csv.mag.idxmax()]
"""
[int, int]: The index for the minimum and maximum values in the `mag` column.
"""
df_csv.loc[mag_min_max_dict, columns_dictionary]
# Out:
#      alert   mag magType                              title  tsunami  \
# 2409   NaN -1.26      ml  M -1.3 - 41km ENE of Adak, Alaska        0
# 5263   red  7.50     mww  M 7.5 - 78km N of Palu, Indonesia        1
#
#             type
# 2409  earthquake
# 5263  earthquake

# %% [markdown]
# #### Using the ``filter()`` Method to Filter a ``DataFrame`` Object
#
# The ``filter()`` method does not filter ``DataFrame`` objects in the same way I've done so far. Here, I'll show multiple ways to use the ``filter()`` method. For example:
#
# * I can grab columns of a ``DataFrame`` instance by passing a list to ``items``:

# %%
items_list = ['mag', 'magType']
"""
[str, str]: The columns to get from my DataFrame instance.
"""
df_csv.filter(items_list).head()
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml
# 3  0.44      ml
# 4  2.16      md

# %% [markdown]
# * I can grab columns of a ``DataFrame`` instance by passing a ``str`` value to the ``like`` parameter.

# %%
df_csv.filter(like = 'mag').head()
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml
# 3  0.44      ml
# 4  2.16      md

# %% [markdown]
# * I can use a regular expression to filter a ``DataFrame`` instance using the ``regex`` argument.

# %%
df_csv.filter(regex = r'^t').head()
# Out:
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0

# %% [markdown]
# * I can also use ``filter()`` along the rows by passsing in ``axis = 0``.
#
# <div class='alert alert-info' role='alert'>
#     I will learn more about the <code>set_index()</code> method in the next chapter.
# </div>

# %%
df_csv.set_index('place').filter(like = 'Japan', axis = 0).filter(items = columns_dictionary).head()
# Out:
#                             alert  mag magType  \
# place
# 160km NNW of Nago, Japan      NaN  4.6      mb
# 7km ESE of Asahi, Japan       NaN  5.2     mww
# 14km E of Tomakomai, Japan    NaN  4.5     mwr
# 139km WSW of Naze, Japan      NaN  4.7      mb
# 53km ESE of Kamaishi, Japan   NaN  4.6      mb
#
#                                                            title  tsunami  \
# place
# 160km NNW of Nago, Japan        M 4.6 - 160km NNW of Nago, Japan        0
# 7km ESE of Asahi, Japan          M 5.2 - 7km ESE of Asahi, Japan        0
# 14km E of Tomakomai, Japan    M 4.5 - 14km E of Tomakomai, Japan        0
# 139km WSW of Naze, Japan        M 4.7 - 139km WSW of Naze, Japan        0
# 53km ESE of Kamaishi, Japan  M 4.6 - 53km ESE of Kamaishi, Japan        0
#
#                                    type
# place
# 160km NNW of Nago, Japan     earthquake
# 7km ESE of Asahi, Japan      earthquake
# 14km E of Tomakomai, Japan   earthquake
# 139km WSW of Naze, Japan     earthquake
# 53km ESE of Kamaishi, Japan  earthquake

# %% [markdown]
# ## Creating Data in a ``DataFrame`` Object
#
# ### Adding New Columns to a ``DataFrame`` Object
#
# When I add a new column to a ``DataFrame`` instance, it will be added to the right end of the instance. Additionally, if I only add one element to the new column, that new element will be **broadcasted** across the rows of the ``DataFrame`` instance.

# %%
new_column_title = 'source'
"""
str: The heading for the new column I want to add.
"""
new_column_element = 'USGS API'
"""
str: The element I want to broadcast down my DataFrame instance.
"""
df_csv[new_column_title] = new_column_element
# I just want to see if the new elements are added
df_csv.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#             time                          title tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA       0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA       0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA       0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA       0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url    source
# 0  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 1  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 2  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 3  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 4  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
#
# [5 rows x 27 columns]

# %% [markdown]
# I can even use a Boolean mask to help build a new column.

# %%
new_column_title = "mag_negative"
new_column_element = df_csv.mag < 0
df_csv[new_column_title] = new_column_element
df_csv.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...           time  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  1539475168010
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  1539475129610
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  1539475062610
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  1539474978070
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  1539474716050
#
#                            title  tsunami        type  \
# 0  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url    source mag_negative
# 0  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        False
# 2  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        False
# 3  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        False
# 4  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        False
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Example: Adding a ``parsed_place`` Column to My ``DataFrame`` Object
#
# Currently, the ``place`` column has several elements that are the same thing but are called something else (example: CA and California).

# %%
df_csv.place.str.extract(r', (.*$)')[0].sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Australia', 'Azerbaijan', 'B.C., MX', 'Barbuda', 'Bolivia',
#        'Bonaire, Saint Eustatius and Saba ', 'British Virgin Islands',
#        'Burma', 'CA', 'California', 'Canada', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Ecuador region',
#        'El Salvador', 'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala',
#        'Haiti', 'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Italy', 'Jamaica', 'Japan', 'Kansas',
#        'Kentucky', 'Kyrgyzstan', 'Martinique', 'Mauritius', 'Mayotte',
#        'Mexico', 'Missouri', 'Montana', 'NV', 'Nevada', 'New Caledonia',
#        'New Hampshire', 'New Mexico', 'New Zealand', 'Nicaragua',
#        'North Carolina', 'Northern Mariana Islands', 'Oklahoma', 'Oregon',
#        'Pakistan', 'Papua New Guinea', 'Peru', 'Philippines',
#        'Puerto Rico', 'Romania', 'Russia', 'Saint Helena',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Carolina',
#        'South Georgia and the South Sandwich Islands',
#        'South Sandwich Islands', 'Taiwan', 'Tajikistan', 'Tennessee',
#        'Texas', 'Tonga', 'Turkey', 'U.S. Virgin Islands', 'Utah',
#        'Uzbekistan', 'Vanuatu', 'Vermont', 'Washington', 'Wyoming',
#        'Yemen', nan], dtype=object)

# %% [markdown]
# The code below will fix that.

# %%
df_csv['parsed_place'] = df_csv.place.str.replace(
    r'.* of ', '', regex=True # remove anything saying <something> of <something>
).str.replace(
    'the ', '' # remove "the "
).str.replace(
    r'CA$', 'California', regex=True # fix California
).str.replace(
    r'NV$', 'Nevada', regex=True # fix Nevada
).str.replace(
    r'MX$', 'Mexico', regex=True # fix Mexico
).str.replace(
    r' region$', '', regex=True # chop off endings with " region"
).str.replace(
    'northern ', '' # remove "northern "
).str.replace(
    'Fiji Islands', 'Fiji' # line up the Fiji places
).str.replace(
    r'^.*, ', '', regex=True # remove anything else extraneous from the beginning
).str.strip() # remove any extra spaces
df_csv.parsed_place.sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Ascension Island', 'Australia', 'Azerbaijan', 'Balleny Islands',
#        'Barbuda', 'Bolivia', 'British Virgin Islands', 'Burma',
#        'California', 'Canada', 'Carlsberg Ridge',
#        'Central East Pacific Rise', 'Central Mid-Atlantic Ridge', 'Chile',
#        'China', 'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'El Salvador',
#        'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala', 'Haiti',
#        'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indian Ocean Triple Junction', 'Indonesia', 'Iran', 'Iraq',
#        'Italy', 'Jamaica', 'Japan', 'Kansas', 'Kentucky',
#        'Kermadec Islands', 'Kuril Islands', 'Kyrgyzstan', 'Martinique',
#        'Mauritius', 'Mayotte', 'Mexico', 'Mid-Indian Ridge', 'Missouri',
#        'Montana', 'Nevada', 'New Caledonia', 'New Hampshire',
#        'New Mexico', 'New Zealand', 'Nicaragua', 'North Carolina',
#        'Northern East Pacific Rise', 'Northern Mariana Islands',
#        'Northern Mid-Atlantic Ridge', 'Oklahoma', 'Oregon',
#        'Pacific-Antarctic Ridge', 'Pakistan', 'Papua New Guinea', 'Peru',
#        'Philippines', 'Prince Edward Islands', 'Puerto Rico',
#        'Queen Charlotte Islands', 'Romania', 'Russia',
#        'Saint Eustatius and Saba', 'Saint Helena', 'Socotra',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Carolina',
#        'South Georgia and South Sandwich Islands',
#        'South Sandwich Islands', 'Southeast Indian Ridge',
#        'Southern East Pacific Rise', 'Southern Mid-Atlantic Ridge',
#        'Southwest Indian Ridge', 'Sumatra', 'Taiwan', 'Tajikistan',
#        'Tennessee', 'Texas', 'Tonga', 'Turkey', 'U.S. Virgin Islands',
#        'Utah', 'Uzbekistan', 'Vanuatu', 'Vermont', 'Washington',
#        'Western Indian-Antarctic Ridge', 'Western Xizang', 'Wyoming',
#        'Yemen'], dtype=object)

# %% [markdown]
# #### Using the ``assign()`` Method to Create Columns in a ``DataFrame`` Object
#
# The ``assign()`` method allows me to create more than 1 column at a time, or update existing columns.

# %%
in_california = df_csv.parsed_place.str.endswith('California')
"""
pandas.core.series.Series: A column for whether the earthquake occurred in California.
"""
in_alaska = df_csv.parsed_place.str.endswith('Alaska')
"""
pandas.core.series.Series: A column for whether the earthquake occurred in Alaska.
"""
number_of_columns_to_sample = 10
"""
int: The number of columns to sample from the original DataFrame instance.
"""
df_csv.assign(
    in_california = df_csv.parsed_place.str.endswith('California'),
    in_alaska = df_csv.parsed_place.str.endswith('Alaska')).sample(number_of_columns_to_sample, random_state = 0)
# Out:
#      alert  cdi      code                                             detail  \
# 7207   NaN  NaN  2000hj64  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4755   NaN  NaN  61424302  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4595   NaN  NaN  20267171  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3566   NaN  NaN  20268839  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2182   NaN  NaN  38316584  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4561   NaN  NaN  20267197  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2379   NaN  NaN  20271488  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2846   NaN  NaN  73093341  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 8600   NaN  NaN  20258931  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4256   NaN  NaN  37374994  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#          dmin  felt    gap                      ids   mag magType  ...  \
# 7207  1.29800   NaN   80.0             ,us2000hj64,  4.80     mwr  ...
# 4755  0.02342   NaN   89.0             ,uw61424302,  1.09      ml  ...
# 4595      NaN   NaN    NaN             ,ak20267171,  1.80      ml  ...
# 3566      NaN   NaN    NaN             ,ak20268839,  1.50      ml  ...
# 2182  0.13390   NaN  128.0             ,ci38316584,  0.90      ml  ...
# 4561      NaN   NaN    NaN  ,ak20267197,us1000h4hb,  2.90      ml  ...
# 2379      NaN   NaN    NaN             ,ak20271488,  1.10      ml  ...
# 2846  0.03050   NaN  139.0             ,nc73093341,  0.44      md  ...
# 8600      NaN   NaN    NaN             ,ak20258931,  1.40      ml  ...
# 4256  0.09785   NaN   35.0             ,ci37374994,  2.15      ml  ...
#
#             type                                              types     tz  \
# 7207  earthquake         ,geoserve,moment-tensor,origin,phase-data, -360.0
# 4755  earthquake                       ,geoserve,origin,phase-data, -480.0
# 4595  earthquake                       ,geoserve,origin,phase-data, -540.0
# 3566  earthquake                       ,geoserve,origin,phase-data, -540.0
# 2182  earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 4561  earthquake                       ,geoserve,origin,phase-data, -540.0
# 2379  earthquake                       ,geoserve,origin,phase-data, -540.0
# 2846  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0
# 8600  earthquake                                  ,geoserve,origin, -540.0
# 4256  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0
#
#             updated                                                url  \
# 7207  1539400902040  https://earthquake.usgs.gov/earthquakes/eventp...
# 4755  1538446772590  https://earthquake.usgs.gov/earthquakes/eventp...
# 4595  1539067248080  https://earthquake.usgs.gov/earthquakes/eventp...
# 3566  1539390064104  https://earthquake.usgs.gov/earthquakes/eventp...
# 2182  1539109448181  https://earthquake.usgs.gov/earthquakes/eventp...
# 4561  1539491199040  https://earthquake.usgs.gov/earthquakes/eventp...
# 2379  1539219549977  https://earthquake.usgs.gov/earthquakes/eventp...
# 2846  1538677923501  https://earthquake.usgs.gov/earthquakes/eventp...
# 8600  1537418635961  https://earthquake.usgs.gov/earthquakes/eventp...
# 4256  1538410222140  https://earthquake.usgs.gov/earthquakes/eventp...
#
#         source mag_negative parsed_place  in_california in_alaska
# 7207  USGS API        False    Nicaragua          False     False
# 4755  USGS API        False   Washington          False     False
# 4595  USGS API        False       Alaska          False      True
# 3566  USGS API        False       Alaska          False      True
# 2182  USGS API        False   California           True     False
# 4561  USGS API        False       Alaska          False      True
# 2379  USGS API        False       Alaska          False      True
# 2846  USGS API        False   California           True     False
# 8600  USGS API        False       Alaska          False      True
# 4256  USGS API        False   California           True     False
#
# [10 rows x 31 columns]

# %% [markdown]
# ##### Using Lambda Functions in the ``assign()`` Method to Create Columns in a ``DataFrame`` Object
#
# With the use of `lambda` functions, the `assign()` method becomes even more powerful.
#
# **Lambda functions** are anonymous functions usually defined in one line and for single use.
#
# The `assign()` method passes the entire dataframe into the `lambda` function as `x`; from there, I can select the columns `in_ca` and `in_alaska`, which are being created in that same call to `assign()`.
#
# Here, I use a `lambda` function to create a new column, `neither`, which tells if the earthquake was neither in Alaska nor California:

# %%
df_csv.assign(
    in_california = df_csv.parsed_place == 'California',
    in_alaska = df_csv.parsed_place == 'Alaska',
    neither = lambda x: ~x.in_california & ~x.in_alaska
).sample(number_of_columns_to_sample, random_state = 0)
# Out:
#      alert  cdi      code                                             detail  \
# 7207   NaN  NaN  2000hj64  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4755   NaN  NaN  61424302  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4595   NaN  NaN  20267171  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3566   NaN  NaN  20268839  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2182   NaN  NaN  38316584  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4561   NaN  NaN  20267197  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2379   NaN  NaN  20271488  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2846   NaN  NaN  73093341  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 8600   NaN  NaN  20258931  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4256   NaN  NaN  37374994  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#          dmin  felt    gap                      ids   mag magType  ...  \
# 7207  1.29800   NaN   80.0             ,us2000hj64,  4.80     mwr  ...
# 4755  0.02342   NaN   89.0             ,uw61424302,  1.09      ml  ...
# 4595      NaN   NaN    NaN             ,ak20267171,  1.80      ml  ...
# 3566      NaN   NaN    NaN             ,ak20268839,  1.50      ml  ...
# 2182  0.13390   NaN  128.0             ,ci38316584,  0.90      ml  ...
# 4561      NaN   NaN    NaN  ,ak20267197,us1000h4hb,  2.90      ml  ...
# 2379      NaN   NaN    NaN             ,ak20271488,  1.10      ml  ...
# 2846  0.03050   NaN  139.0             ,nc73093341,  0.44      md  ...
# 8600      NaN   NaN    NaN             ,ak20258931,  1.40      ml  ...
# 4256  0.09785   NaN   35.0             ,ci37374994,  2.15      ml  ...
#
#                                                   types     tz        updated  \
# 7207         ,geoserve,moment-tensor,origin,phase-data, -360.0  1539400902040
# 4755                       ,geoserve,origin,phase-data, -480.0  1538446772590
# 4595                       ,geoserve,origin,phase-data, -540.0  1539067248080
# 3566                       ,geoserve,origin,phase-data, -540.0  1539390064104
# 2182         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539109448181
# 4561                       ,geoserve,origin,phase-data, -540.0  1539491199040
# 2379                       ,geoserve,origin,phase-data, -540.0  1539219549977
# 2846  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1538677923501
# 8600                                  ,geoserve,origin, -540.0  1537418635961
# 4256  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1538410222140
#
#                                                     url    source  \
# 7207  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 4755  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 4595  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 3566  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 2182  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 4561  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 2379  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 2846  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 8600  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 4256  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
#
#       mag_negative parsed_place in_california  in_alaska neither
# 7207         False    Nicaragua         False      False    True
# 4755         False   Washington         False      False    True
# 4595         False       Alaska         False       True   False
# 3566         False       Alaska         False       True   False
# 2182         False   California          True      False   False
# 4561         False       Alaska         False       True   False
# 2379         False       Alaska         False       True   False
# 2846         False   California          True      False   False
# 8600         False       Alaska         False       True   False
# 4256         False   California          True      False   False
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Concatenating ``DataFrame`` Objects with the ``pd.concat()`` Method
#
# I can use the ``pd.concat([DataFrame_1, DataFrame_2], axis = 0)`` to append ``DataFrame_2`` to the bottom of ``DataFrame_1``.

# %%
tsunami = df_csv[df_csv.tsunami == 1]
"""
pandas.core.frame.DataFrame: A DataFrame instance that includes all earthquakes that led to a tsunami.
"""
no_tsunami = df_csv[df_csv.tsunami == 0]
"""
pandas.core.frame.DataFrame: A DataFrame instance that includes all earthquakes that did not lead to a tsunami.
"""
pd.concat([tsunami, no_tsunami], axis = 0)
# Out:
#       alert  cdi        code  \
# 36      NaN  NaN    1000hbsa
# 118   green  NaN    1000hbkz
# 501   green  NaN    1000hax9
# 799   green  NaN    1000hacw
# 816   green  NaN    1000habl
# ...     ...  ...         ...
# 9327    NaN  NaN    73086771
# 9328    NaN  NaN    38063967
# 9329    NaN  NaN  2018261000
# 9330    NaN  NaN    38063959
# 9331    NaN  NaN    38063935
#
#                                                  detail     dmin  felt    gap  \
# 36    https://earthquake.usgs.gov/fdsnws/event/1/que...  1.54100   NaN   51.0
# 118   https://earthquake.usgs.gov/fdsnws/event/1/que...  2.62300   NaN   25.0
# 501   https://earthquake.usgs.gov/fdsnws/event/1/que...  2.35600   NaN   45.0
# 799   https://earthquake.usgs.gov/fdsnws/event/1/que...  3.87900   NaN   18.0
# 816   https://earthquake.usgs.gov/fdsnws/event/1/que...  0.90700   NaN   12.0
# ...                                                 ...      ...   ...    ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01806   NaN  185.0
# 9328  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.03041   NaN   50.0
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.45260   NaN  276.0
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01865   NaN   61.0
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01698   NaN   39.0
#
#                                      ids   mag magType  ...  \
# 36                          ,us1000hbsa,  5.00     mww  ...
# 118   ,pt18286001,at00pgjb1a,us1000hbkz,  6.70     mww  ...
# 501                         ,us1000hax9,  5.60     mww  ...
# 799   ,pt18283004,at00pgeomo,us1000hacw,  6.50     mww  ...
# 816                         ,us1000habl,  6.20     mww  ...
# ...                                  ...   ...     ...  ...
# 9327                        ,nc73086771,  0.62      md  ...
# 9328                        ,ci38063967,  1.00      ml  ...
# 9329                      ,pr2018261000,  2.40      md  ...
# 9330                        ,ci38063959,  1.10      ml  ...
# 9331                        ,ci38063935,  0.66      ml  ...
#
#                                                   title tsunami        type  \
# 36    M 5.0 - 165km NNW of Flying Fish Cove, Christm...       1  earthquake
# 118             M 6.7 - 262km NW of Ozernovskiy, Russia       1  earthquake
# 501         M 5.6 - 128km SE of Kimbe, Papua New Guinea       1  earthquake
# 799          M 6.5 - 148km S of Severo-Kuril'sk, Russia       1  earthquake
# 816         M 6.2 - 94km SW of Kokopo, Papua New Guinea       1  earthquake
# ...                                                 ...     ...         ...
# 9327               M 0.6 - 9km ENE of Mammoth Lakes, CA       0  earthquake
# 9328                        M 1.0 - 3km W of Julian, CA       0  earthquake
# 9329           M 2.4 - 35km NNE of Hatillo, Puerto Rico       0  earthquake
# 9330                      M 1.1 - 9km NE of Aguanga, CA       0  earthquake
# 9331                      M 0.7 - 9km NE of Aguanga, CA       0  earthquake
#
#                                                   types     tz        updated  \
# 36                         ,geoserve,origin,phase-data,  420.0  1539461285040
# 118   ,geoserve,ground-failure,impact-link,losspager...  600.0  1539455437040
# 501   ,geoserve,losspager,moment-tensor,origin,phase...  600.0  1539359431040
# 799   ,geoserve,ground-failure,impact-link,losspager...  600.0  1539224915040
# 816   ,geoserve,ground-failure,losspager,moment-tens...  600.0  1539219109963
# ...                                                 ...    ...            ...
# 9327         ,geoserve,nearby-cities,origin,phase-data, -480.0  1537285598315
# 9328  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1537276800970
# 9329                       ,geoserve,origin,phase-data, -240.0  1537243777410
# 9330  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537230211640
# 9331  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537305830770
#
#                                                     url    source  \
# 36    https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 118   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 501   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 799   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 816   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# ...                                                 ...       ...
# 9327  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9328  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9329  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9330  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9331  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
#
#       mag_negative      parsed_place
# 36           False  Christmas Island
# 118          False            Russia
# 501          False  Papua New Guinea
# 799          False            Russia
# 816          False  Papua New Guinea
# ...            ...               ...
# 9327         False        California
# 9328         False        California
# 9329         False       Puerto Rico
# 9330         False        California
# 9331         False        California
#
# [9332 rows x 29 columns]

# %% [markdown]
# I can also change the ``pd.concat([...], axis = 0)`` argument to ``axis = 1`` to add more columns to the right end of the ``DataFrame`` instance.

# %%
get_columns = ['tz', 'felt', 'ids']
"""
list(str): A set of columns I want to add to my DataFrame instance.
"""
n_rows_to_get = 2
"""
int: The number of rows to return from the updated DataFrame instance.
"""
additional_columns = pd.read_csv(csv_file_path, usecols = get_columns)
"""
pandas.core.frame.DataFrame: A DataFrame instance with some columns I want to retrieve.
"""
build_list = [df_csv.head(n_rows_to_get), additional_columns.head(n_rows_to_get)]
"""
list(pandas.core.frame.DataFrame, pandas.core.frame.DataFrame): An expanded DataFrame instance.
"""
pd.concat(build_list, axis = 1)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin felt   gap           ids   mag magType  ...  \
# 0  0.008693  NaN  85.0  ,ci37389218,  1.35      ml  ...
# 1  0.020030  NaN  79.0  ,ci37389202,  1.29      ml  ...
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url    source  mag_negative  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API         False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API         False
#
#   parsed_place felt           ids     tz
# 0   California  NaN  ,ci37389218, -480.0
# 1   California  NaN  ,ci37389202, -480.0
#
# [2 rows x 32 columns]

# %% [markdown]
# #### Using the ``join`` Parameter to Concatenate ``DataFrame`` Objects
#
# The ``join`` parameter specifies how to handle any overlap in column names (when appending to the bottom) or in row names (when concatenating to the left/right).
#
# By default, this is ``outer``, everything. However, if I use ``inner``, I will only keep what is in common between ``DataFrame`` objects.

# %%
pd.concat(
    [tsunami.head(2), no_tsunami.head(2).assign(type = 'earthquake')], join = 'inner'
)
# Out:
#      alert  cdi      code                                             detail  \
# 36     NaN  NaN  1000hbsa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118  green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 0      NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1      NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#          dmin  felt   gap                                 ids   mag magType  \
# 36   1.541000   NaN  51.0                        ,us1000hbsa,  5.00     mww
# 118  2.623000   NaN  25.0  ,pt18286001,at00pgjb1a,us1000hbkz,  6.70     mww
# 0    0.008693   NaN  85.0                        ,ci37389218,  1.35      ml
# 1    0.020030   NaN  79.0                        ,ci37389202,  1.29      ml
#
#      ...                                              title tsunami  \
# 36   ...  M 5.0 - 165km NNW of Flying Fish Cove, Christm...       1
# 118  ...            M 6.7 - 262km NW of Ozernovskiy, Russia       1
# 0    ...                      M 1.4 - 9km NE of Aguanga, CA       0
# 1    ...                      M 1.3 - 9km NE of Aguanga, CA       0
#
#            type                                              types     tz  \
# 36   earthquake                       ,geoserve,origin,phase-data,  420.0
# 118  earthquake  ,geoserve,ground-failure,impact-link,losspager...  600.0
# 0    earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 1    earthquake         ,geoserve,nearby-cities,origin,phase-data, -480.0
#
#            updated                                                url  \
# 36   1539461285040  https://earthquake.usgs.gov/earthquakes/eventp...
# 118  1539455437040  https://earthquake.usgs.gov/earthquakes/eventp...
# 0    1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...
# 1    1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...
#
#        source  mag_negative      parsed_place
# 36   USGS API         False  Christmas Island
# 118  USGS API         False            Russia
# 0    USGS API         False        California
# 1    USGS API         False        California
#
# [4 rows x 29 columns]

# %% [markdown]
# ##### Using the ``ignore_index`` with the ``join`` Parameter
#
# If I don't care about the indices, I can use the ``ignore_index`` parameter with the ``join`` parameter. This will give me sequential values instead of what was demonstrated above.

# %%
pd.concat(
    [tsunami.head(2), no_tsunami.head(2).assign(type = 'earthquake')], join = 'inner', ignore_index = True
)
# Out:
#    alert  cdi      code                                             detail  \
# 0    NaN  NaN  1000hbsa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1  green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2    NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3    NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap                                 ids   mag magType  \
# 0  1.541000   NaN  51.0                        ,us1000hbsa,  5.00     mww
# 1  2.623000   NaN  25.0  ,pt18286001,at00pgjb1a,us1000hbkz,  6.70     mww
# 2  0.008693   NaN  85.0                        ,ci37389218,  1.35      ml
# 3  0.020030   NaN  79.0                        ,ci37389202,  1.29      ml
#
#    ...                                              title tsunami        type  \
# 0  ...  M 5.0 - 165km NNW of Flying Fish Cove, Christm...       1  earthquake
# 1  ...            M 6.7 - 262km NW of Ozernovskiy, Russia       1  earthquake
# 2  ...                      M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 3  ...                      M 1.3 - 9km NE of Aguanga, CA       0  earthquake
#
#                                                types     tz        updated  \
# 0                       ,geoserve,origin,phase-data,  420.0  1539461285040
# 1  ,geoserve,ground-failure,impact-link,losspager...  600.0  1539455437040
# 2         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url    source  mag_negative  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API         False
# 1  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API         False
# 2  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API         False
# 3  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API         False
#
#        parsed_place
# 0  Christmas Island
# 1            Russia
# 2        California
# 3        California
#
# [4 rows x 29 columns]

# %% [markdown]
# ### Deleting Unwanted Data from a ``DataFrame`` Object
#
# #### Deleting Unwanted Data froma a ``DataFrame`` Object Using the ``del`` Command
#
# I can use dictionary syntax and the ``del`` command to remove data from a ``DataFrame`` instance.
#
# Before the deletion.

# %%
column_to_delete = 'sources'
"""
str: The column heading for the column I want to delete from my DataFrame instance.
"""
df_csv.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'source', 'mag_negative', 'parsed_place'],
#       dtype='object')

# %% [markdown]
# After the deletion.

# %%
del df_csv[column_to_delete]
df_csv.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url', 'source',
#        'mag_negative', 'parsed_place'],
#       dtype='object')

# %% [markdown]
# It is a good idea to pair the ``del`` command with a ``try``/``except`` block.

# %%
try:
    del df_csv[column_to_delete]
except KeyError:
    print(f'The {column_to_delete} column is not in this DataFrame instance anymore.')
# Out:
# The sources column is not in this DataFrame instance anymore.

# %% [markdown]
# #### Removing Data from a ``DataFrame`` Object Using the ``pop()`` Method
#
# I can also use the ``pop()`` method to remove a column from a ``DataFrame`` instance. The beauty of this method is that the popped column is not permanently deleted. It is, instead, returned as a ``Series`` instance.

# %%
column_to_pop = 'mag_negative'
"""
str: The column heading for the column I want to pop out of the DataFrame instance.
"""
popped_column = df_csv.pop(column_to_pop)
"""
pandas.core.series.Series: The column I popped out of my DataFrame instance.
"""
print(type(popped_column))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_csv
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# 9328  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.030410   NaN
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.452600   NaN
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018650   NaN
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.016980   NaN
#
#         gap             ids   mag magType  ...           time  \
# 0      85.0    ,ci37389218,  1.35      ml  ...  1539475168010
# 1      79.0    ,ci37389202,  1.29      ml  ...  1539475129610
# 2      21.0    ,ci37389194,  3.42      ml  ...  1539475062610
# 3      39.0    ,ci37389186,  0.44      ml  ...  1539474978070
# 4     192.0    ,nc73096941,  2.16      md  ...  1539474716050
# ...     ...             ...   ...     ...  ...            ...
# 9327  185.0    ,nc73086771,  0.62      md  ...  1537230228060
# 9328   50.0    ,ci38063967,  1.00      ml  ...  1537230135130
# 9329  276.0  ,pr2018261000,  2.40      md  ...  1537229908180
# 9330   61.0    ,ci38063959,  1.10      ml  ...  1537229545350
# 9331   39.0    ,ci38063935,  0.66      ml  ...  1537228864470
#
#                                          title  tsunami        type  \
# 0                M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1                M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2                M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3                M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4                M 2.2 - 10km NW of Avenal, CA        0  earthquake
# ...                                        ...      ...         ...
# 9327      M 0.6 - 9km ENE of Mammoth Lakes, CA        0  earthquake
# 9328               M 1.0 - 3km W of Julian, CA        0  earthquake
# 9329  M 2.4 - 35km NNE of Hatillo, Puerto Rico        0  earthquake
# 9330             M 1.1 - 9km NE of Aguanga, CA        0  earthquake
# 9331             M 0.7 - 9km NE of Aguanga, CA        0  earthquake
#
#                                                   types     tz        updated  \
# 0            ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1            ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2     ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3            ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4     ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
# ...                                                 ...    ...            ...
# 9327         ,geoserve,nearby-cities,origin,phase-data, -480.0  1537285598315
# 9328  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1537276800970
# 9329                       ,geoserve,origin,phase-data, -240.0  1537243777410
# 9330  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537230211640
# 9331  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537305830770
#
#                                                     url    source  \
# 0     https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 1     https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 2     https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 3     https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 4     https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# ...                                                 ...       ...
# 9327  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9328  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9329  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9330  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
# 9331  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API
#
#       parsed_place
# 0       California
# 1       California
# 2       California
# 3       California
# 4       California
# ...            ...
# 9327    California
# 9328    California
# 9329   Puerto Rico
# 9330    California
# 9331    California
#
# [9332 rows x 27 columns]

# %%
# This column solely exist to include the variable name in a markdown cell.
# The import I need to do to display text as Markdown.
# from IPython.display import Markdown as md

# %% [markdown]
# Notice that the popped column has a mask in it.

# %%
popped_column
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9327    False
# 9328    False
# 9329    False
# 9330    False
# 9331    False
# Name: mag_negative, Length: 9332, dtype: bool

# %% [markdown]
# I can use the popped column to filter my data.

# %%
df_csv[popped_column].head()
# Out:
#     alert  cdi      code                                             detail  \
# 39    NaN  NaN  00660886  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 49    NaN  NaN  00660884  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 135   NaN  NaN  00660897  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 161   NaN  NaN  80314084  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 198   NaN  NaN  00660745  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt     gap           ids   mag magType  ...           time  \
# 39   0.095   NaN  155.25  ,nn00660886, -0.10      ml  ...  1539458844506
# 49   0.097   NaN  155.98  ,nn00660884, -0.10      ml  ...  1539455017464
# 135  0.092   NaN   71.82  ,nn00660897, -0.40      ml  ...  1539422175717
# 161  0.148   NaN  117.00  ,mb80314084, -0.02      md  ...  1539412475360
# 198  0.047   NaN   65.16  ,nn00660745, -0.20      ml  ...  1539398340822
#
#                                         title  tsunami        type  \
# 39   M -0.1 - 6km NW of Lemmon Valley, Nevada        0  earthquake
# 49   M -0.1 - 6km NW of Lemmon Valley, Nevada        0  earthquake
# 135       M -0.4 - 10km SSE of Beatty, Nevada        0  earthquake
# 161       M -0.0 - 20km SSE of Ronan, Montana        0  earthquake
# 198        M -0.2 - 60km N of Pahrump, Nevada        0  earthquake
#
#                             types     tz        updated  \
# 39   ,geoserve,origin,phase-data, -480.0  1539482703428
# 49   ,geoserve,origin,phase-data, -480.0  1539482700579
# 135  ,geoserve,origin,phase-data, -480.0  1539482715521
# 161  ,geoserve,origin,phase-data, -420.0  1539433905970
# 198  ,geoserve,origin,phase-data, -480.0  1539482652322
#
#                                                    url    source  parsed_place
# 39   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        Nevada
# 49   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        Nevada
# 135  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        Nevada
# 161  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API       Montana
# 198  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        Nevada
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Using the ``drop()`` Method to Drop Rows from a ``DataFrame`` Object
#
# I can use the ``drop()`` method to drop specific rows from a ``DataFrame`` instance.

# %%
rows_to_drop = [0, 10]
"""
[int, int]: The indices to drop from my DataFrame instance.
"""
df_csv.drop([0, 1, 2, 3, 4, 5]).head(5)
# Out:
#    alert  cdi      code                                             detail  \
# 6    NaN  NaN  20280432  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 7    NaN  NaN  73096936  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 8    NaN  NaN  73096931  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9    NaN  NaN  1000hbtn  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 10   NaN  NaN  37389162  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt   gap           ids   mag magType  ...           time  \
# 6        NaN   NaN   NaN  ,ak20280432,  1.70      ml  ...  1539473176017
# 7   0.016220   NaN  83.0  ,nc73096936,  1.13      md  ...  1539473060280
# 8   0.009138   NaN  52.0  ,nc73096931,  0.92      md  ...  1539473042310
# 9   3.191000   NaN  37.0  ,us1000hbtn,  4.70      mb  ...  1539472814760
# 10  0.005116   NaN  57.0  ,ci37389162,  0.50      ml  ...  1539471831030
#
#                                       title  tsunami        type  \
# 6      M 1.7 - 105km W of Talkeetna, Alaska        0  earthquake
# 7          M 1.1 - 10km NW of Parkfield, CA        0  earthquake
# 8         M 0.9 - 6km NW of The Geysers, CA        0  earthquake
# 9   M 4.7 - 219km SSE of Saparua, Indonesia        0  earthquake
# 10           M 0.5 - 10km NE of Aguanga, CA        0  earthquake
#
#                                                 types     tz        updated  \
# 6                                   ,geoserve,origin, -540.0  1539473596465
# 7   ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539476642808
# 8   ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539475027632
# 9                        ,geoserve,origin,phase-data,  540.0  1539473712040
# 10         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539472054436
#
#                                                   url    source  parsed_place
# 6   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API        Alaska
# 7   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API    California
# 8   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API    California
# 9   https://earthquake.usgs.gov/earthquakes/eventp...  USGS API     Indonesia
# 10  https://earthquake.usgs.gov/earthquakes/eventp...  USGS API    California
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Using the ``drop()`` Method to Drop Columns from a ``DataFrame`` Object
#
# Using the ``columns`` argument allows me to drop columns from a ``DataFrame`` instance. The same can be done by using ``axis = 1`` argument.

# %%
colums_to_drop_list = ['alert', 'mag', 'title', 'time', 'tsunami']
columns_to_drop = [
    col for col in df_csv.columns if col not in colums_to_drop_list
]
df_csv.drop(columns = columns_to_drop).head()
# Out:
#   alert   mag           time                          title  tsunami
# 0   NaN  1.35  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0
# 1   NaN  1.29  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0
# 2   NaN  3.42  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0
# 3   NaN  0.44  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0
# 4   NaN  2.16  1539474716050  M 2.2 - 10km NW of Avenal, CA        0

# %% [markdown]
# By default, ``drop()``, along with the majority of ``DataFrame`` methods, will return a new ``DataFrame`` object. If we I want to change the one we are working with, we can pass ``inplace=True``.
#
# <div class='alert alert-warning' role='alert'>
#     <span>Be very careful if I choose to do this.</span>
# </div>

# %%
df_csv.drop(columns = columns_to_drop, inplace = True)
df_csv.head()
# Out:
#   alert   mag           time                          title  tsunami
# 0   NaN  1.35  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0
# 1   NaN  1.29  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0
# 2   NaN  3.42  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0
# 3   NaN  0.44  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0
# 4   NaN  2.16  1539474716050  M 2.2 - 10km NW of Avenal, CA        0
